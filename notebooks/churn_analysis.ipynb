# %% [markdown]
# # Customer Churn Analysis (IBM Telco)
# This notebook covers data loading, cleaning, exploratory analysis, feature engineering, and model training (Logistic Regression & Random Forest).

# %%
import pandas as pd
import numpy as np
from src.churn.utils import load_data, clean_data, kpis, train_models

df = load_data()
df = clean_data(df)
df.head()

# %% [markdown]
# ## KPIs

# %%
metrics = kpis(df)
metrics

# %% [markdown]
# ## Train Models

# %%
results = train_models(df)
results = {k: {kk: (vv if kk!= 'report' else vv) for kk, vv in v.items()} for k, v in results.items()}
{k: {'auc': v['auc']} for k, v in results.items()}
